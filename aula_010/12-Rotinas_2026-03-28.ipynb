# %% [markdown]
# # Explicação Rotina
#
# https://1drv.ms/v/c/808ebfd9a0d86213/IQA1p5nBtUMiS4C1k70ZRFf3ASpmGVhaRHc_ibt9GJbkfww?e=9Er6z5

# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Cite três vantagens do uso das funções e duas características que toda função deva ter?

# %% [markdown]
# R.: Evita codigo repetitivo. Permite maior abstração de processos dentro do codigo. Facilita a organização do script.
# Uma função deve ser pura, não deve alterar valores instanciados fora dela.
# Uma função não deve modificar os valores de seus argumentos, apenas de variaveis dentro do escopo da propria função.

# %% [markdown]
# ## Responda a pergunta do exercício 2 da aula 10, usando funções:<br>
# Instancie um objeto da classe NumPy array, contendo 5 valores quantitativos randômicos normalmente distribuídos, com média 10 e desvio padrão 3.<br><br>
# Quantos e quais são os valores superiores a 10?

# %%
import numpy as np

# %% [markdown]
# ## 02 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Separado para abstração como argumento um np.ndarray, assim a funçaõ funciona com qualquer tipo de array numpy, em seguida inicia um contador, para cada item do array, caso o valor seja maior que 10 ele adiciona um no contador, no fim o retorno da função é uma mensagem amigável avisando quantos itens acima de 10 existem ali e a matriz avaliada

# %% [markdown]
# ## 03 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 04 – Escreva o programa em Python:

# %%
matriz_exercicio_2_numpy = np.random.normal(10, 3, 5)
def maior_que_dez(matriz:np.ndarray):
  count_up_ten = 0
  for i in range(len(matriz)):
    if matriz[i] > 10:
      count_up_ten += 1
  return f'Número de elementos maiores que 10: {count_up_ten}, matriz: {matriz}'

maior_que_dez(matriz_exercicio_2_numpy)
# Out:
# 'Número de elementos maiores que 10: 1, matriz: [ 5.01476617  7.0907538  13.2641418   9.96114594  6.66784364]'

# %% [markdown]
# ## 05 – Seria possível, com o racional proposto, saber quantos e quais valores são superiores a 20? Porque?

# %% [markdown]
# Não pq não adicionei como argumento o valor que seria avaliado, para tal a função deveria sera justado.

# %% [markdown]
# ## Desenvolva um programa de computador que retorne a média de um conjunto de valores.

# %% [markdown]
# ## 06 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: A função recebe um conjunto de valores iteraveis como uma lista, calcula a média somando todos os valores, e divide pelo tamanho do conjunto de valores.

# %% [markdown]
# ## 07 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 07 – Escreva o programa em Python:

# %%
def media_custom(items:list):
  return sum(items) / len(items)

# %% [markdown]
# ## 09 – Desenvolva um programa de computador que retorne a divisão de dois objetos simples. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divisao_simples( denominador, divisor):
  if (type(denominador) != int or type(divisor) != int) and (type(denominador) != float or type(divisor) != float):
    raise TypeError('Os argumentos devem ser int ou float para executar a divisão')
  if(divisor == 0):
    raise ValueError('Divisor nao pode ser zero')
  divisao = denominador / divisor
  print(f'Resultado da divisão: {divisao}, valor do tipo {type(divisao)}')
  return divisao


divisao_simples(10, 2)
# Out:
# Resultado da divisão: 5.0, valor do tipo <class 'float'>
# 5.0

# %% [markdown]
# ## 10 – Desenvolva um programa de computador que retorne a divisão de dois objetos compostos. Seu programa deve ser capaz de reconhecer a classe destes objetos e o valor, antes de retornar ao usuário.

# %%
def divisao_composto(denominador, divisor):
  print(f'Denominador: {denominador} do tipo {type(denominador)}, divisor: {divisor}, do tipo {type(divisor)}')
  try:
    divisao = denominador / divisor
    print(f'Resultado da divisão: {divisao}, com o tipo {type(divisao)}')
  except ZeroDivisionError:
    print('Divisor nao pode ser zero')
  except TypeError:
    print('O tipo do argumento deve ser divisivel, sendo um array numpy')
  return divisao

lista_a = np.array([1,2,3])
lista_b = lista_a * 10
lista_c = lista_a/ lista_b

divisao_composto(lista_a, lista_b)
lista_c
# Out:
# Denominador: [1 2 3] do tipo <class 'numpy.ndarray'>, divisor: [10 20 30], do tipo <class 'numpy.ndarray'>
# Resultado da divisão: [0.1 0.1 0.1], com o tipo <class 'numpy.ndarray'>
# array([0.1, 0.1, 0.1])
