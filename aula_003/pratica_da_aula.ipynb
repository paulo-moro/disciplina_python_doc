# %%
lamps = [
  "ligada",
  "desligada",
  "desligada",
  "ligada",
  "desligada"
]

# %%
print(lamps[1:5:2])
# Out:
# ['desligada', 'ligada']

# %%
lamp_1, lamp_2, lamp_3, lamp_4, lamp_5 = lamps
print(lamp_1)
print(lamp_2)
print(lamp_3)
print(lamp_4)
# Out:
# ligada
# desligada
# desligada
# ligada

# %%
obj_dict = {
  "str": "str",
  "int": 42,
  "float": 4.2,
  "bool": True,
  "complex": 1 + 2j,
  "list": [1, 2, 3],
  "tuple": (1, 2, 3),
  "set": {1, 2, 3},
  "bytes": b"byte",
  "dict": {"key": "value"},
}
obj_dict["str"]
# Out:
# 'str'

# %%
obj_set = {1, 2, 3}

# %%
obj_tuple = (1, 2, 3)

# %%
lista_com_type:list[str] = ["str", "str", "str"]

lista_com_type.append("str")
print(lista_com_type)

lista_com_type.append(42)  
print(lista_com_type)
# Out:
# ['str', 'str', 'str', 'str']
# ['str', 'str', 'str', 'str', 42]
