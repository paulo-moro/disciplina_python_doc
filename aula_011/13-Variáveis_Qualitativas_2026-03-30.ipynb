# %% [markdown]
# # Exercício:

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df_data = pd.read_csv('../storage/aula_004.csv')
df_data.drop('gene_name', axis=1)
# Out:
#   BRCA1 TP53 EGFR VEGFA APOE
# 0     5    4    4     5    4
# 1    BR   TP   EG    VE   AP
# 2     1    0    0     1    1
# 3     0    0    0     0    0

# %% [markdown]
# ## Importe o .csv utilizado no exercício 7 da aula 11 e instancie um objeto da classe DataFrame. Considere que não há uma ordem entre os genes.
# Como inserir  na DataFrame uma tabela de frequência do número de caracteres no nome dos genes? Uma vez inserida, como obter um gráfico de barras deste dado?

# %% [markdown]
# ## 01 – Descreva o racional da sua resposta:

# %% [markdown]
# R.: Primeiro adiciono os rotulos de cada linha, fazendo a transposição do dataset, na sequencia faço o calculo da frequencia de cada name_len, depois indexo a frequencia do name len com cada gene e depois faço o plot do grafico com o name_len, a principio mostrando as frequencias de cada name_len

# %% [markdown]
# ## 02 – Desenhe o fluxograma da resposta:

# %% [markdown]
# <img src="./img/diagrama.jpg"/>

# %% [markdown]
# ## 03 – Escreva o programa em Python:

# %%
row_names = ['name_len', 'first_second_char', 'a_count', 'hu_count']
df_t = df_data.T
df_t.columns = row_names
df_name_len = df_t['name_len'].value_counts().to_frame()
freq_name_len = df_t['name_len'].value_counts(normalize=True)
df_t['freq_name_len'] = df_t['name_len'].map(freq_name_len)
df_data= df_t.T
print(df_t)
sns.countplot(
    x='name_len',
    data=df_t
)
plt.xlabel('Número de caracteres')
plt.ylabel('Frequência')
plt.title('Frequência do número de caracteres no nome dos genes')
plt.show()
# Out:
#           name_len first_second_char a_count hu_count  freq_name_len
# gene_name        0                 1       2        3       0.166667
# BRCA1            5                BR       1        0       0.333333
# TP53             4                TP       0        0       0.500000
# EGFR             4                EG       0        0       0.500000
# VEGFA            5                VE       1        0       0.333333
# APOE             4                AP       1        0       0.500000

# %% [markdown]
# ## Importe o .csv utilizado no exercício 7 da aula 11 e instancie um objeto da classe DataFrame. Considere que há uma ordem entre os genes.
# Como inserir  na DataFrame uma tabela de frequência do número de caracteres no nome dos genes? Uma vez inserida, como obter um gráfico de barras deste dado?

# %% [markdown]
# ## 04 – Descreva o racional da sua resposta:

# %% [markdown]
# R.:

# %% [markdown]
# ## 05 – Desenhe o fluxograma da resposta:

# %% [markdown]
# ## 06 – Escreva o programa em Python:

# %% [markdown]
# ## 07 – Reorganize a DataFrame, removendo as colunas contendo os dois primeiros caracteres, o número de caracter 'a', e a presença de 'hu', dos genes. Renomeie as colunas de acordo com as informações. Adicione uma coluna com a informação de 'Amostra 1'.

# %%
df_droped = df_t.drop(['a_count', 'hu_count', 'first_second_char'], axis=1)

df_droped = df_droped.rename(columns={'name_len': 'amostra_1'})
df_droped = df_droped.rename(columns={'freq_name_len': 'freq_amostra_1'})

print(df_droped)
# Out:
#           amostra_1  freq_amostra_1
# gene_name         0        0.166667
# BRCA1             5        0.333333
# TP53              4        0.500000
# EGFR              4        0.500000
# VEGFA             5        0.333333
# APOE              4        0.500000

# %% [markdown]
# ## 08 – Usando a função randint(), da classe random do módulo numpy (np.random.randint(1,10,5)), instancie objeto da classe numpy array. Calcule as frequências desta nova amostra, considerando que à uma ordem entre os genes. Insira na DataFrame este objeto como "Amostra 2".

# %%
import numpy as np


def adicionar_frequencia(amostra:pd.DataFrame, coluna:str):
  amostra2 = np.random.randint(1, 10, 6)
  amostra[coluna] = amostra2
  freq_name_len = amostra[coluna].value_counts(normalize=True)
  amostra[f'freq_{coluna}'] = amostra[coluna].map(freq_name_len)
  
adicionar_frequencia(df_droped, 'amostra_2')
print(df_droped)
# Out:
#           amostra_1  freq_amostra_1  amostra_2  freq_amostra_2
# gene_name         0        0.166667          6        0.166667
# BRCA1             5        0.333333          1        0.166667
# TP53              4        0.500000          8        0.166667
# EGFR              4        0.500000          9        0.166667
# VEGFA             5        0.333333          3        0.166667
# APOE              4        0.500000          2        0.166667

# %% [markdown]
# ## 09 – Repita o exercício 8, inserindo na DataFrame as replicas "Amostra 3“, "Amostra 4“, "Amostra 5“ e "Amostra 6".

# %%
adicionar_frequencia(df_droped, 'amostra_3')
adicionar_frequencia(df_droped, 'amostra_4')
adicionar_frequencia(df_droped, 'amostra_5')
adicionar_frequencia(df_droped, 'amostra_6')
print(df_droped)
# Out:
#           amostra_1  freq_amostra_1  amostra_2  freq_amostra_2  amostra_3  \
# gene_name         0        0.166667          6        0.166667          2
# BRCA1             5        0.333333          1        0.166667          9
# TP53              4        0.500000          8        0.166667          9
# EGFR              4        0.500000          9        0.166667          9
# VEGFA             5        0.333333          3        0.166667          7
# APOE              4        0.500000          2        0.166667          6
#
#            freq_amostra_3  amostra_4  freq_amostra_4  amostra_5  \
# gene_name        0.166667          7        0.333333          6
# BRCA1            0.500000          9        0.166667          5
# TP53             0.500000          4        0.166667          1
# EGFR             0.500000          2        0.166667          8
# VEGFA            0.166667          6        0.166667          4
# APOE             0.166667          7        0.333333          1
#
#            freq_amostra_5  amostra_6  freq_amostra_6
# gene_name        0.166667          9        0.333333
# BRCA1            0.166667          9        0.333333
# TP53             0.333333          8        0.333333
# EGFR             0.166667          4        0.166667
# VEGFA            0.166667          7        0.166667
# APOE             0.333333          8        0.333333

# %% [markdown]
# ## 10 – Obtenha dos seus dados o gráfico abaixo, adicionando 3 replicas.
